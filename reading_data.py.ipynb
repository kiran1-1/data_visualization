# %%
import pandas as pd
import missingno as msno 
df = pd.read_csv("melb_data.csv")

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
pd.read_csv('melb_data.csv',nrows=5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.iloc[:5, :]
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_null_values = df[df.isna().any(axis=1)]
df_null_values.iloc[:, :]
# Out:
#               Suburb             Address  Rooms Type      Price Method  \
# 0         Abbotsford        85 Turner St      2    h  1480000.0      S
# 3         Abbotsford    40 Federation La      3    h   850000.0     PI
# 5         Abbotsford      129 Charles St      2    h   941000.0      S
# 8         Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 10        Abbotsford  411/8 Grosvenor St      2    u   700000.0     VB
# ...              ...                 ...    ...  ...        ...    ...
# 13575  Wheelers Hill        12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown       77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown         83 Power St      3    h  1170000.0      S
# 13578   Williamstown        96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville          6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.isnull().any().sum()
# Out:
# 4

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Car                62
# Propertycount       0
# Date                0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Bedroom2            0
# Distance            0
# Postcode            0
# Regionname          0
# Bathroom            0
# Landsize            0
# Lattitude           0
# Longtitude          0
# Suburb              0
# dtype: int64

# %%
df_null_values.shape
# Out:
# (7384, 21)

# %%
df.shape
# Out:
# (13580, 21)

# %%
 df_percent = df.isnull().sum()*100/len(df)
df_percent.sort_values(ascending = False)
# Out:
# BuildingArea     47.496318
# YearBuilt        39.580265
# CouncilArea      10.081001
# Car               0.456554
# Propertycount     0.000000
# Date              0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Bedroom2          0.000000
# Distance          0.000000
# Postcode          0.000000
# Regionname        0.000000
# Bathroom          0.000000
# Landsize          0.000000
# Lattitude         0.000000
# Longtitude        0.000000
# Suburb            0.000000
# dtype: float64

# %%
df_rows_with_notnull = df.dropna()
df_rows_with_notnull.shape
# Out:
# (6196, 21)

# %%
df.iloc[:5 , :]
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_null_values.shape
# Out:
# (7384, 21)

# %%
df_filling_with_meanvalues = df.fillna(df.mean())
print(df_filling_with_meanvalues)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_null_values = df[df.isna().any(axis=1)]
df_null_values.shape
# Out:
# (7384, 21)

# %%
df_filling_with_meanvalues.iloc[:5, :]
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0     151.96765
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0      79.00000
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0     150.00000
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0     151.96765
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0     142.00000
#
#      YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_interpolate = df.interpolate()
print(df_interpolate)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_interpolate.iloc[:5, :]
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0         146.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_null_values = df[df.isna().any(axis=1)]
df_null_values.shape
# Out:
# (7384, 21)

# %%
#making a copy of dataset 
df_copyfor_column_mean = df.copy()
df_copyfor_column_mean
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
msno.matrix(df_copyfor_column_mean)
# Out:
# <AxesSubplot:>

# %%
#  df_columnnames_nullvalues = df.columns[df.isnull().any()].tolist()
# print(df_columnnames_nullvalues)


# df_only_numric_columns = df.select_dtypes(exclude=["object"])

# df_columnnames_numric_nullvalues = df_only_numric_columns.columns[df_only_numric_columns.isnull().any()].tolist()

# print(df_columnnames_numric_nullvalues)

# df_null_values_numric = df_only_numric_columns[df_only_numric_columns.isna().any(axis=1)]
# df_null_values_numric.shape

df_columnnames_nullvalues = df_copyfor_column_mean.columns[df_copyfor_column_mean.isnull().any()].tolist()
print(df_columnnames_nullvalues)


df_only_numric_columns = df_copyfor_column_mean.select_dtypes(exclude=["object"])

df_columnnames_numric_nullvalues = df_only_numric_columns.columns[df_only_numric_columns.isnull().any()].tolist()

print(df_columnnames_numric_nullvalues)
# Out:
# ['Car', 'BuildingArea', 'YearBuilt', 'CouncilArea']
# ['Car', 'BuildingArea', 'YearBuilt']

# %%
for i in df_columnnames_numric_nullvalues:
    print(df_copyfor_column_mean[i][:10])
# Out:
# 0    1.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    2.0
# 5    0.0
# 6    0.0
# 7    2.0
# 8    1.0
# 9    2.0
# Name: Car, dtype: float64
# 0      NaN
# 1     79.0
# 2    150.0
# 3      NaN
# 4    142.0
# 5      NaN
# 6    210.0
# 7    107.0
# 8      NaN
# 9     75.0
# Name: BuildingArea, dtype: float64
# 0       NaN
# 1    1900.0
# 2    1900.0
# 3       NaN
# 4    2014.0
# 5       NaN
# 6    1910.0
# 7    1890.0
# 8       NaN
# 9    1900.0
# Name: YearBuilt, dtype: float64

# %%
# df_null_values = df[df.isna().any(axis=1)]
# df_null_values.shape
df_copyfor_column_mean["YearBuilt"]
# Out:
# 0           NaN
# 1        1900.0
# 2        1900.0
# 3           NaN
# 4        2014.0
#           ...
# 13575    1981.0
# 13576    1995.0
# 13577    1997.0
# 13578    1920.0
# 13579    1920.0
# Name: YearBuilt, Length: 13580, dtype: float64

# %%
import numpy as np
for i in df_columnnames_numric_nullvalues:
    df_copyfor_column_mean[i] = df_copyfor_column_mean[i].replace(np.NaN, df_copyfor_column_mean[i].mean())
msno.matrix(df_copyfor_column_mean)
# Out:
# <AxesSubplot:>

# %%
df_copyfor_column_mean["YearBuilt"]
# Out:
# 0        1964.684217
# 1        1900.000000
# 2        1900.000000
# 3        1964.684217
# 4        2014.000000
#             ...
# 13575    1981.000000
# 13576    1995.000000
# 13577    1997.000000
# 13578    1920.000000
# 13579    1920.000000
# Name: YearBuilt, Length: 13580, dtype: float64

# %%
df_copyfor_column_mean
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_null_values = df[df.isna().any(axis=1)]
df_null_values.shape
# Out:
# (7384, 21)

# %%
df_null_values = df_copyfor_column_mean[df_copyfor_column_mean.isna().any(axis=1)]
df_null_values.shape
# Out:
# (1369, 21)
